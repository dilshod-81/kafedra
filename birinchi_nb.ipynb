# %% [markdown]
# <a href="https://colab.research.google.com/github/dilshod-81/kafedra/blob/main/birinchi_nb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('salom')
# Out:
# salom

# %%
import torch

# %%
torch.__version__
# Out:
# '1.13.1+cu116'

# %% [markdown]
# #Heading
# - [Kirish ](https://mohirdev.uz)
# - Muqaddima

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
! ls
# Out:
# sample_data

# %%
import pandas as pd
files = pd.read_excel('./data/Хисобдан чикариш.xlsx')
files.head(20)
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                         Организация
# 6                                                 NaN
# 7                     Структурная единица организации
# 8                                                 NaN
# 9   Основание для проведения инвентаризации: прика...
# 10                                                NaN
# 11                                                NaN
# 12                                  Основные средства
# 13                                                NaN
# 14                                    Местонахождение
# 15                                                NaN
# ...
